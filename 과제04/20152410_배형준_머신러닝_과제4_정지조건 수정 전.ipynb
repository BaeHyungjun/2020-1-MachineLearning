# %% [markdown]
# # 20152410 배형준 머신러닝 과제4

# %%
# library import

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Plot the estimated parameters using the training dataset

# %%
# set my local working directory

import os

directory = 'C:\\Users\\golds\\Desktop\\중앙대학교\\2020-1 4학년 1학기\\머신러닝'
os.chdir(directory)

# %%
# load trainset and testset

train_directory = './과제4/data_train.csv'
test_directory = './과제4/data_test.csv'

train = pd.read_csv(train_directory, header=None)
test = pd.read_csv(test_directory, header=None)

column_name = ['x', 'y', 'z', 'h']
train.columns = column_name
test.columns = column_name

X_train = train.iloc[:, 0:3]
X_test = test.iloc[:, 0:3]
Y_train = train.iloc[:, 3]
Y_test = test.iloc[:, 3]

# %%
train.head()
# Out:
#           x         y          z          h
# 0  0.273548 -8.932102  18.708684  73.578825
# 1  5.403327  4.782977 -18.762210 -56.410433
# 2  0.029941 -3.245916   6.932498  52.390768
# 3  3.047974  0.715211  -1.965419  -6.936295
# 4  1.302074 -5.871807 -15.702181 -34.997017

# %%
test.head()
# Out:
#           x          y          z          h
# 0 -1.788894  -2.717927  -4.425695 -14.055818
# 1  2.958174   4.515505   6.644435  20.504905
# 2 -0.569490  10.096246 -13.270292 -73.843148
# 3  4.279318   2.747878  -5.857125 -24.644937
# 4  0.125975  -4.349421   5.777460  31.934657

# %%
# 변수들이 어떤 상관관계를 가지고 있는지 체크

plt.figure(figsize=(18, 6))
plt.subplot(231)
plt.scatter(X_train.iloc[:, 0], X_train.iloc[:, 1], alpha=0.3)
plt.title('X and Y')
plt.subplot(232)
plt.scatter(X_train.iloc[:, 0], X_train.iloc[:, 2], alpha=0.3)
plt.title('X and Z')
plt.subplot(233)
plt.scatter(X_train.iloc[:, 1], X_train.iloc[:, 2], alpha=0.3)
plt.title('Y and Z')
plt.subplot(234)
plt.scatter(X_train.iloc[:, 0], Y_train, alpha=0.3)
plt.title('X and H')
plt.subplot(235)
plt.scatter(X_train.iloc[:, 1], Y_train, alpha=0.3)
plt.title('Y and H')
plt.subplot(236)
plt.scatter(X_train.iloc[:, 2], Y_train, alpha=0.3)
plt.title('Z and H')
plt.show()

# %% [markdown]
# feature간의 다중공선성이 강한 것으로 보아 선형회귀를 학습할 때 계수 추정이 제대로 이뤄지지 않을 것을 예상할 수 있다.
#
# 다른 말로 표현하자면 normal equation으로 선형회귀의 계수 추정을 할 때 $X^T*X$가 non-invertible하거나 invertible이지만 rank가 모자란 상황이라고 볼 수 있다.
#
# 밑에 있는 make_regression 함수를 여러 번 돌려본 결과 수렴할 때가 있고 수렴하지 않을 때가 있는데 이것은 theta의 초기값의 랜덤성때문이라고 생각한다. 따라서 setseed (random_state)를 지정하여 여러 번 돌려본 후 학습 알고리즘이 수렴하는지, 수렴한다면 theta 값은 어떻게 되는지 결과를 비교하도록 하겠다.

# %%
def make_regression(X_train, Y_train, X_test, Y_test, seed):
    
    # set random initial condition of parameters
    
    m = len(Y_train)
    n = len(Y_test)
    X_train = np.hstack((np.ones((m, 1)), np.array(X_train)))
    X_test = np.hstack((np.ones((n, 1)), np.array(X_test)))
    Y_train = np.array(Y_train).reshape(-1, 1)
    Y_test = np.array(Y_test).reshape(-1, 1)
    
    np.random.seed(seed)
    initial_theta = np.random.randn(4, 1)
    record_theta = initial_theta.T
    
    initial_train_loss = (Y_train - X_train.dot(initial_theta)).T.dot(Y_train - X_train.dot(initial_theta)) / (2*m)
    initial_test_loss = (Y_test - X_test.dot(initial_theta)).T.dot(Y_test - X_test.dot(initial_theta)) / (2*n)
    
    list_train_loss = [float(initial_train_loss)]
    list_test_loss = [float(initial_test_loss)]

    temp_theta = initial_theta
    temp_train_loss = initial_train_loss
    
    learning_rate = 10**(-6)
    error_bound = 10**(-5)

    # model learning

    while True:
        # calculate gradient
        gradient_theta = (X_train.T.dot(X_train).dot(temp_theta) - X_train.T.dot(Y_train)) / m
    
        # renew the parameters
        next_theta = temp_theta - learning_rate * gradient_theta
        temp_theta = next_theta
    
        # calculate loss to evaluate the parameters
        next_train_loss = (Y_train - X_train.dot(next_theta)).T.dot(Y_train - X_train.dot(next_theta)) / (2*m)
        test_loss = (Y_test - X_test.dot(next_theta)).T.dot(Y_test - X_test.dot(next_theta)) / (2*n)
    
        # store results
        record_theta = np.vstack((record_theta, temp_theta.T))
        list_train_loss.append(float(next_train_loss))
        list_test_loss.append(float(test_loss))
        
        # stopping rule
        if len(list_train_loss) > 50000:
            #if temp_train_loss > next_train_loss and temp_train_loss - next_train_loss < error_bound:
            break
            #if list_train_loss[-1] > list_train_loss[-10]:
             #   break # 초기값이나 학습률의 문제로 loss가 발산했을 때 학습을 멈추고 함수를 고치기 위한 용도
            #if len(list_train_loss) < 10000:
             #   break # 초기값이나 학습률의 문제로 loss가 발산했을 때 학습을 멈추고 함수를 고치기 위한 용도
                
        temp_train_loss = next_train_loss
    
    result_theta = record_theta[-1, :]
    
    return result_theta, record_theta, list_train_loss, list_test_loss

# %% [markdown]
# 학습 알고리즘의 정지 조건은 5000번 이상 실행한 후 i+1번째의 loss가 i번째의 loss보다 error_bound 이하로 감소하면 학습을 종료한다.
#
# 10000번 넘어서도 학습이 완료되지 않으면 초기값 문제로 알고리즘이 수렴하지 않을 수 있고 그 이유로는 X_train 변수 간 다중 공선성이 강해서라고 생각합니다. (어떤 경우엔 잘 학습되지만 어떤 경우엔 알고리즘이 수렴하지 않아 계속 실행됨)
#
# y축의 범위에 따라 theta의 변화가 시각적으로 다르게 체감될 수 있으므로 y축의 범위를 plt.ylim((-1, 3))로 고정하고 진행하도록 하겠다.

# %% [markdown]
# ## make regression with random_state = 568

# %%
result_theta_568, record_theta_568, list_train_loss_568, list_test_loss_568 = make_regression(X_train, Y_train, X_test, Y_test, 568)

# %%
result_theta_568
# Out:
# array([ 0.93830366, -0.07883656, -0.93127424,  4.0070482 ])

# %%
print(list_train_loss_568[-1], len(list_train_loss_568))
# Out:
# 119.36174982617537 50001

# %%
# plot of theta0 ~ theta3

plt.figure(figsize=(15, 6))
plt.plot(record_theta_568[:, 0], 'k', label='theta0')
plt.plot(record_theta_568[:, 1], 'r', label='theta1')
plt.plot(record_theta_568[:, 2], 'g', label='theta2')
plt.plot(record_theta_568[:, 3], 'b', label='theta3')
plt.legend(loc='best')
plt.ylim((-2, 5))
plt.show()

# %%
# 그래프가 겹치는 것을 고려하여 각각 출력

plt.figure(figsize=(15, 6))
plt.subplot(221)
plt.plot(record_theta_568[:, 0], 'k', label='theta0')
plt.title('theta0')
plt.ylim((-1, 3))
plt.subplot(222)
plt.plot(record_theta_568[:, 1], 'r', label='theta1')
plt.title('theta1')
plt.ylim((-1, 3))
plt.subplot(223)
plt.plot(record_theta_568[:, 2], 'g', label='theta2')
plt.title('theta2')
plt.ylim((-1, 3))
plt.subplot(224)
plt.plot(record_theta_568[:, 3], 'b', label='theta3')
plt.title('theta3')
plt.ylim((-1, 3))
plt.show()

# %% [markdown]
# ## make regression with random_state = 4489

# %%
result_theta_4489, record_theta_4489, list_train_loss_4489, list_test_loss_4489 = make_regression(X_train, Y_train, X_test, Y_test, 4489)

# %%
# plot of theta0 ~ theta3

plt.figure(figsize=(15, 6))
plt.plot(record_theta_4489[:, 0], 'k', label='theta0')
plt.plot(record_theta_4489[:, 1], 'r', label='theta1')
plt.plot(record_theta_4489[:, 2], 'g', label='theta2')
plt.plot(record_theta_4489[:, 3], 'b', label='theta3')
plt.legend(loc='best')
plt.ylim((-1, 3))
plt.show()

# %%
# 그래프가 겹치는 것을 고려하여 각각 출력

plt.figure(figsize=(15, 6))
plt.subplot(221)
plt.plot(record_theta_4489[:, 0], 'k', label='theta0')
plt.title('theta0')
plt.ylim((-1, 3))
plt.subplot(222)
plt.plot(record_theta_4489[:, 1], 'r', label='theta1')
plt.title('theta1')
plt.ylim((-1, 3))
plt.subplot(223)
plt.plot(record_theta_4489[:, 2], 'g', label='theta2')
plt.title('theta2')
plt.ylim((-1, 3))
plt.subplot(224)
plt.plot(record_theta_4489[:, 3], 'b', label='theta3')
plt.title('theta3')
plt.ylim((-1, 3))
plt.show()

# %% [markdown]
# ## make regression with random_state = 241

# %%
result_theta_241, record_theta_241, list_train_loss_241, list_test_loss_241 = make_regression(X_train, Y_train, X_test, Y_test, 241)

# %%
# plot of theta0 ~ theta3

plt.figure(figsize=(15, 6))
plt.plot(record_theta_241[:, 0], 'k', label='theta0')
plt.plot(record_theta_241[:, 1], 'r', label='theta1')
plt.plot(record_theta_241[:, 2], 'g', label='theta2')
plt.plot(record_theta_241[:, 3], 'b', label='theta3')
plt.legend(loc='best')
plt.ylim((-1, 3))
plt.show()

# %%
# 그래프가 겹치는 것을 고려하여 각각 출력

plt.figure(figsize=(15, 6))
plt.subplot(221)
plt.plot(record_theta_241[:, 0], 'k', label='theta0')
plt.title('theta0')
plt.ylim((-1, 3))
plt.subplot(222)
plt.plot(record_theta_241[:, 1], 'r', label='theta1')
plt.title('theta1')
plt.ylim((-1, 3))
plt.subplot(223)
plt.plot(record_theta_241[:, 2], 'g', label='theta2')
plt.title('theta2')
plt.ylim((-1, 3))
plt.subplot(224)
plt.plot(record_theta_241[:, 3], 'b', label='theta3')
plt.title('theta3')
plt.ylim((-1, 3))
plt.show()

# %% [markdown]
# 초기값때문에 학습 알고리즘이 수렴하지 않아 실패한 경우도 있었지만 결과를 첨부할 수 없어서 학습이 성공한 3개의 사례를 비교해보도록 하겠다.
#
# 3개의 경우 모두 학습을 성공적으로 마치긴 했지만 random_state에 따라서 parameter들의 결과가 달라진 것을 확인할 수 있다.

# %% [markdown]
# # 2. Plot the training error using the training dataset

# %%
plt.figure(figsize=(10, 4))
plt.plot(list_train_loss_568, 'b')
plt.title('train error when random_state = 568')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(list_train_loss_4489, 'b')
plt.title('train error when random_state = 4489')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(list_train_loss_241, 'b')
plt.title('train error when random_state = 241')
plt.show()

# %%
print('random_state가 568일 때 학습은 {}번 반복했고 최종 train error는 {}이다.'.format(len(list_train_loss_568),
                                                                      list_train_loss_568[-1]))
# Out:
# random_state가 568일 때 학습은 50001번 반복했고 최종 train error는 119.36174982617537이다.

# %%
print('random_state가 4489일 때 학습은 {}번 반복했고 최종 train error는 {}이다.'.format(len(list_train_loss_4489),
                                                                       list_train_loss_4489[-1]))
# Out:
# random_state가 4489일 때 학습은 50001번 반복했고 최종 train error는 106.21276439001379이다.

# %%
print('random_state가 241일 때 학습은 {}번 반복했고 최종 train error는 {}이다.'.format(len(list_train_loss_241),
                                                                      list_train_loss_241[-1]))
# Out:
# random_state가 241일 때 학습은 50001번 반복했고 최종 train error는 105.148597805989이다.

# %% [markdown]
# 3번의 학습 결과, 초기값에 따라서 train_loss의 시작이 확연하게 차이나는 것을 확인할 수 있다.
#
# 같은 정지 조건을 가졌음에도 theta가 수렴하는 지점도 다르고 train_loss가 수렴한 값도 다른 것을 알 수 있다.

# %% [markdown]
# # 3. Plot the testing error using the testing dataset at every iteration of gradient descent until convergence

# %%
plt.figure(figsize=(10, 4))
plt.plot(list_test_loss_568, 'r')
plt.title('test error when random_state = 568')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(list_test_loss_4489, 'r')
plt.title('test error when random_state = 4489')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(list_test_loss_241, 'r')
plt.title('test error when random_state = 241')
plt.show()

# %%
print('random_state가 568일 때 최종 test error는 {}이다.'.format(list_test_loss_568[-1]))
# Out:
# random_state가 568일 때 최종 test error는 22.2934692583831이다.

# %%
print('random_state가 4489일 때 최종 test error는 {}이다.'.format(list_test_loss_4489[-1]))
# Out:
# random_state가 4489일 때 최종 test error는 5.563795108906712이다.

# %%
print('random_state가 241일 때 최종 test error는 {}이다.'.format(list_test_loss_241[-1]))
# Out:
# random_state가 241일 때 최종 test error는 3.550521482818317이다.

# %% [markdown]
# 3번의 학습 결과 random_state에 따라 test error의 시작점이 다르고 수렴한 값도 다른 것을 확인할 수 있다.
#
# 긍정적인 점은 train error가 감소하며 모델이 잘 적합될수록 test error도 같이 잘 감소하는 모습을 보인다.
#
# => 모델이 train을 얼마나 잘 학습했냐와는 별개로 적어도 모델이 train에 과대적합하지는 않았다고 볼 수 있다.

# %% [markdown]
# # 정규방정식(Normal equation)으로 구한 결과와 random_state=241일때의 경사하강법으로 구한 결과를 비교

# %%
x_train = np.hstack((np.ones((len(Y_train), 1)), X_train))
x_test = np.hstack((np.ones((len(Y_test), 1)), X_test))

theta_hat_ne = np.linalg.inv(x_train.T.dot(x_train)).dot(x_train.T).dot(Y_train)
train_loss_ne = (Y_train - x_train.dot(theta_hat_ne)).T.dot(Y_train - x_train.dot(theta_hat_ne)) / (2*len(Y_train))
test_loss_ne = (Y_test - x_test.dot(theta_hat_ne)).T.dot(Y_test - x_test.dot(theta_hat_ne)) / (2*len(Y_test))

print(' 정규방정식으로 구한 theta_hat : {} \n 경사하강법으로 구한 theta_hat : {}'.format(theta_hat_ne, result_theta_241))
# Out:
#  정규방정식으로 구한 theta_hat : [-1.19220481  0.79285367 -1.7943636   4.00796887]
#  경사하강법으로 구한 theta_hat : [ 1.24413759  0.62784736 -1.59015546  3.95690852]

# %%
sst = np.sum((Y_train - np.mean(Y_train))**2)
sse_ne = train_loss_ne * (2*len(Y_train))
sse_241 = list_train_loss_241[-1] * (2*len(Y_train))

# %%
print('train의 종속변수의 SST는 {}이고 정규방정식 결과의 SSE는 {}, 경사하강법 결과의 SSE는 {}이다.'.format(sst, sse_ne, sse_241))
# Out:
# train의 종속변수의 SST는 20751934.1333317이고 정규방정식 결과의 SSE는 62072.3096785274, 경사하강법 결과의 SSE는 63089.1586835934이다.

# %%
print('train 데이터에 대한 R^2값으로 비교해보면 정규방정식의 R^2는 {}, 경사하강법의 R^2는 {}이다.'.format(1-sse_ne/sst, 1-sse_241/sst))
# Out:
# train 데이터에 대한 R^2값으로 비교해보면 정규방정식의 R^2는 0.997008842198529, 경사하강법의 R^2는 0.9969598419945706이다.

# %%
print('test 데이터에 대한 error를 비교해보면 정규방정식의 test error는 {}이고 경사하강법의 test error는 {}이다.'.format(
    list_test_loss_241[-1] ,test_loss_ne))
# Out:
# test 데이터에 대한 error를 비교해보면 정규방정식의 test error는 3.550521482818317이고 경사하강법의 test error는 0.9914725974039151이다.

# %% [markdown]
# 먼저 parameters를 추정한 결과를 비교해보면 값이 많이 다른 것을 알 수 있다. 부호가 반대인 파라미터도 보이고 같은 부호라도 10배 가량 값이 차이나는 파라미터도 있다.
#
# train error를 측정하는 식 중 하나인 Sum of Square Error를 비교해보면 값이 9배 가량 차이나는 것을 확인할 수 있다. 하지만 Sum of Square Total에 대한 비율인 $R^2$로 확인했을 땐 2%p 정도로 크게 차이나지 않는 것을 확인할 수 있다. theta_hat이 완전 다른 것에 비해 $R^2$는 크게 다르지 않는 상황이 이상하다.
#
# train error를 측정하는 $R^2$는 크게 차이나지 않는 반면 test error는 각각 0.99와 1014.45로 1000배 가량 차이나는 것을 확인할 수 있다. test error로 모델의 성능을 측정하는 기준의 잣대로 바라봤을 땐 정규방정식을 통해 구한 모델의 성능이 압도적으로 높은 것을 확인할 수 있다.
#
# 그렇다면 왜 경사하강법으로 구한 모델의 성능이 정규방정식보다 낮은가 또는 경사하강법으로 구한 모델이 왜 제대로 학습하지 못했냐를 따져볼 수 있을 것이다. 위에서도 언급했듯이 x, y, z간의 다중공선성이 강해서 h와의 관계식에서의 계수 추정을 제대로 못한 것이 주요한 이유라고 생각한다.
#
# 이번 데이터는 4차원 데이터라 지난 과제에서 출력했던 surface plot을 출력하지 못하지만 만약에 출력한다면 엄청 길고 평평한 골짜기가 있는 plot이 출력될 것이라고 추정한다.

# %%
corr = train.corr()
corr.style.background_gradient(cmap='coolwarm')

# 위에 scatter plot에서도 확인했듯이 변수간의 선형 상관관계가 0.98 이상으로 매우 강한 것을 알 수 있다.
# Out:
# <style  type="text/css" >
#     #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row0_col1 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row0_col2 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row0_col3 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row1_col0 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row2_col0 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row2_col1 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row2_col3 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row3_col2 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_7ef59f00_7f00_11ea_a5e6_28e3476af834row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >x</th>        <th class="col_heading level0 col1" >y</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >h</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834level0_row0" class="row_heading level0 row0" >x</th>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row0_col1" class="data row0 col1" >0.997343</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row0_col2" class="data row0 col2" >0.991728</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row0_col3" class="data row0 col3" >0.984305</td>
#             </tr>
#             <tr>
#                         <th id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834level0_row1" class="row_heading level0 row1" >y</th>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row1_col0" class="data row1 col0" >0.997343</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row1_col2" class="data row1 col2" >0.990663</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row1_col3" class="data row1 col3" >0.980638</td>
#             </tr>
#             <tr>
#                         <th id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834level0_row2" class="row_heading level0 row2" >z</th>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row2_col0" class="data row2 col0" >0.991728</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row2_col1" class="data row2 col1" >0.990663</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row2_col3" class="data row2 col3" >0.997004</td>
#             </tr>
#             <tr>
#                         <th id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834level0_row3" class="row_heading level0 row3" >h</th>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row3_col0" class="data row3 col0" >0.984305</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row3_col1" class="data row3 col1" >0.980638</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row3_col2" class="data row3 col2" >0.997004</td>
#                         <td id="T_7ef59f00_7f00_11ea_a5e6_28e3476af834row3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>
